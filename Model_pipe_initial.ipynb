# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, os, sys
from sklearn.linear_model import RidgeClassifier, LogisticRegression, LogisticRegressionCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import make_union, make_pipeline, Pipeline, FeatureUnion
from nltk.tokenize import wordpunct_tokenize, TweetTokenizer, word_tokenize
from functools import reduce
from sklearn.model_selection import cross_val_predict, cross_val_score, ShuffleSplit, StratifiedShuffleSplit, StratifiedKFold
from sklearn.metrics import roc_auc_score, log_loss, accuracy_score
from scipy.sparse import hstack
import gc

# %%
#Read data
input_path = "../input"
TRAIN_DATA_FILE = os.path.join(input_path, "train.csv")
TEST_DATA_FILE  = os.path.join(input_path, "test.csv")

train = pd.read_csv(TRAIN_DATA_FILE)
test = pd.read_csv(TEST_DATA_FILE)

print("Shape of train and test", train.shape, test.shape)
print(train.columns, test.columns)
# Out:
# Shape of train and test (159571, 8) (153164, 2)
# Index(['id', 'comment_text', 'toxic', 'severe_toxic', 'obscene', 'threat',
#        'insult', 'identity_hate'],
#       dtype='object') Index(['id', 'comment_text'], dtype='object')

# %%
#clean and normalize text
#TODO - pass for now
gc.collect()
# Out:
# 21

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %%
#make a dummy variable to make stratified kfold work - 
train['target_str'] = reduce(lambda x,y: x+y, [train[col].astype(str) for col in label_cols])
print(train['target_str'].nunique())
#train['target_str'].value_counts()
# Out:
# 41

# %%
#Generate train, val and test sets
cvfold = list(StratifiedKFold(n_splits=10, shuffle=True, random_state=786).split(train, train['target_str'].astype('category')))
print(cvfold[0][0].shape)
# Out:
# /home/mohsin/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# (143600,)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MaxAbsScaler
class ExtraFeats(BaseEstimator, TransformerMixin):
    
    def  __init__(self, regex_feats=True):
        self.regex_feats = regex_feats

    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        if isinstance(X, pd.Series):
            num_bullets = X.str.count("\n\s{0,2}\d{1}\.")
            num_lines = X.str.count("\n\n")
            num_sent = X.str.count("[a-z]\. ")
            indented = X.str.contains(":{2,}").astype(int)
            num_chars = X.str.count("[a-z]")
            num_nums = X.str.count("[0-9]")
            num_words = X.str.count("\s+")
            big_cap_words = X.str.count("\s[A-Z]{3,}\s")
            grammar_aware = X.str.count("[a-z]. [A-Z]")
            exclaims = X.str.count("!{2,}")
            other_syms = X.str.count("@*$")
            
            X = pd.concat([num_bullets, num_lines, num_sent, indented, num_chars, num_nums, num_words, big_cap_words,
                      grammar_aware, exclaims, other_syms], axis=1)
            return X
        else:
            raise ValueError("Need pandas series as input")

# %%
def predict_proba_corr(preds, target_mean):
    #preds = self.predict_proba(X)[:,1]
    d0 = target_mean
    d1 = 1 - d0
    r0 = np.mean(preds)
    r1 = 1 - r0
    gamma_0 = r0/d0
    gamma_1 = r1/d1
    return gamma_1*preds/(gamma_1*preds + gamma_0*(1 - preds))

# %%
# %%time
#Generate features
vec1 = TfidfVectorizer(ngram_range=(2,4), analyzer="char",
               min_df=3, max_df=0.8, strip_accents='unicode', use_idf=1,
               smooth_idf=1, sublinear_tf=1, max_features=50000)
vec2 = TfidfVectorizer(ngram_range=(1,1), analyzer="word",
               min_df=3, max_df=0.8, strip_accents='unicode', use_idf=1,
               smooth_idf=1, sublinear_tf=1, max_features=20000)

feats = ExtraFeats()
scaler = MaxAbsScaler()
pipe = Pipeline([("extra", feats), ('scaler', scaler)])
vec = FeatureUnion(
    [("char", vec1), ("word", vec2) ])

vec.fit(pd.concat([train["comment_text"], test["comment_text"]]))
X = vec.transform(train["comment_text"])
X_test = vec.transform(test["comment_text"])

print(X.shape, X_test.shape)
# Out:
# (159571, 70000) (153164, 70000)
# CPU times: user 6min 6s, sys: 7.93 s, total: 6min 14s
# Wall time: 6min 21s

# %%
y_trues = train[label_cols].values
y_preds = np.zeros((X.shape[0], len(label_cols)))
y_test_preds = np.zeros((X_test.shape[0], len(label_cols)))
for i, col in enumerate(label_cols):
    y = y_trues[:, i]
    model = LogisticRegression(C=1, class_weight='balanced', dual=True, solver='liblinear', max_iter=100)
    y_preds[:, i] = cross_val_predict(model, X, y, cv=cvfold, n_jobs=8, method='predict_proba')[:,1]
    y_test_preds[:, i] = model.fit(X, y).predict_proba(X_test)[:, 1]
    print("Score for class {} is {}".format(col, roc_auc_score(y, y_preds[:, i])))
    gc.collect()
print("Over auc score", roc_auc_score(y_trues, y_preds))
# Out:
# Score for class toxic is 0.9799718607742347
# Score for class severe_toxic is 0.9881731052992774
# Score for class obscene is 0.9916685033641188
# Score for class threat is 0.9913258085643283
# Score for class insult is 0.9839446638680656
# Score for class identity_hate is 0.9831088856012038
# Over auc score 0.9863654712452047

# %%
print(train[label_cols].mean())
print(np.mean(y_preds, axis=0))
# Out:
# toxic            0.095844
# severe_toxic     0.009996
# obscene          0.052948
# threat           0.002996
# insult           0.049364
# identity_hate    0.008805
# dtype: float64
# [0.16366391 0.03567404 0.09288439 0.01485738 0.10154052 0.03675854]

# %%
y_preds_corr = np.zeros(y_preds.shape)
for i, col in enumerate(label_cols):
    mean = train[col].mean()
    #y_preds_corr[:, i] = predict_proba_corr(y_preds[:, i], mean)
    y_preds_corr[:, i] = y_preds[:, i]/np.mean(y_preds[:, i])*mean
    print("Score for col {} is {}".format(col, roc_auc_score(train[col], y_preds_corr[:, i])))
    
print("Overall score is {}".format(roc_auc_score(y_trues, y_preds_corr)))
# Out:
# Score for col toxic is 0.9799718607742347
# Score for col severe_toxic is 0.9881731052992774
# Score for col obscene is 0.9916685033641188
# Score for col threat is 0.9913258085643283
# Score for col insult is 0.9839446638680656
# Score for col identity_hate is 0.9831088856012038
# Overall score is 0.9863654712452047

# %%
#check distribution of coefs
for i in range(6):
    sns.distplot(y_preds[:, i])
    sns.distplot(y_test_preds[:, i])
    plt.show()

# %%
sns.distplot(model.coef_)
plt.show()
print(sum(sum(np.abs(model.coef_) < 0.01)))
# Out:
# 5949

# %%
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
y_trues = train[label_cols].values
y_preds2 = np.zeros((X.shape[0], len(label_cols)))
y_test_preds2 = np.zeros((X_test.shape[0], len(label_cols)))
for i, col in enumerate(label_cols):
    y = y_trues[:, i]
    #model = RandomForestClassifier(n_estimators=100, max_depth=6, min_samples_leaf=50, class_weight='balanced', n_jobs=-1)
    model = lgb.LGBMClassifier(n_estimators=150, num_leaves=8, learning_rate=0.05, class_weight='balanced', 
                               subsample=0.7, colsample_bytree=0.9, verbose=1)
    y_preds2[:, i] = cross_val_predict(model, y_preds, y, cv=cvfold, 
                                       n_jobs=1, method='predict_proba', verbose=1)[:,1]
    y_test_preds2[:, i] = model.fit(y_preds, y).predict_proba(y_test_preds)[:,1]
    print("Score for class {} is {}".format(col, roc_auc_score(y, y_preds2[:, i])))
print("Overall auc score", roc_auc_score(y_trues, y_preds2))
# Out:
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    7.1s finished
# Score for class toxic is 0.98111153693292
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    3.9s finished
# Score for class severe_toxic is 0.9900822004945635
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    5.5s finished
# Score for class obscene is 0.9915933829356538
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    4.8s finished
# Score for class threat is 0.9903314295233279
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    3.8s finished
# Score for class insult is 0.985572415023604
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    3.8s finished
# Score for class identity_hate is 0.9837249710572563
# Overall auc score 0.9870693226612209

# %%
for i in range(6):
    sns.distplot(y_preds2[:, i])
    sns.distplot(y_test_preds2[:, i])
    plt.show()

# %%
sample_submission = pd.read_csv('../input/sample_submission.csv')
sample_submission[label_cols] = y_test_preds2
sample_submission.to_csv('logreg_submission.csv', index=False)

# %%
sample_submission.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.997452      0.975625  0.996793  0.978598  0.992851
# 1  0000247867823ef7  0.005072      0.001956  0.003621  0.001580  0.006791
# 2  00013b17ad220c46  0.014744      0.001516  0.003919  0.001364  0.004598
# 3  00017563c3f7919a  0.002755      0.001648  0.001880  0.001320  0.002356
# 4  00017695ad8997eb  0.135160      0.001405  0.012840  0.001538  0.037414
#
#    identity_hate
# 0       0.982283
# 1       0.006124
# 2       0.003130
# 3       0.002440
# 4       0.004334

# %%
y_err = np.abs(y_preds - y_trues)
mask = y_err[:, 0] > 0.9
train.loc[mask]
# Out:
#                       id                                       comment_text  \
# 61      0022cf8467ebc9fd  A Bisexual, like a homosexual or a heterosexua...
# 175     006b888560bcdfcd                     "know the sex of the foetus"""
# 179     006d11791d76b9f3  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 368     00eb6533c271bc85  hate is my topic is hate\nif you hate a person...
# 503     0152f55962c4f707  I don't care what you say here. I don't believ...
# 527     01625cc84c6ef15b  How do you know he is dead.  Its just his plan...
# 590     018e6f1e1b18723a  "\n\n Another crap article \nParrots what prom...
# 831     0242375ae7ece3b0               OH GET A LIFE YOU PRICK 81.144.199.2
# 923     028aa892076cf0d1                              You are a funney man.
# 946     029a4ebfed3aea79  Speaking without knowing what I'm talking abou...
# 1132    030ff39db5af91fa  Keep your propaganda away from this article. Y...
# 1150    031c15507901e54a  Oh hear me go someone removes all my pages i g...
# 1430    03d425c71927aef4  How dare you block me without cause you had no...
# 1495    04044a4591faac27                      Did you poop in your pants? —
# 1555    042e184200690387  {{unblock|i said im sorry......how do u expect...
# 1624    045a7cdcbe340e8d  You know what? Don't offend other users , you ...
# 1657    047c213edcb89ebd  All I do is revert vandalism.  It's all there ...
# 1952    05476e7b7750269d  Wow J Delanoy, you must really love Brit Hume ...
# 2322    0640e0bf385935a2  "\nMFNickster, I am not sure if you have ever ...
# 2378    066473de21c43cf0  Not really sure what the issue is here \n\nWha...
# 2412    0678fe61d0ebd1ca  "\n\n This article is a perfect example of dou...
# 2494    06a44c69b4c3fb43  In response to your recent comment on my talk ...
# 2537    06c8c299abebc705  "\nLecture someone else, Sarah. You are talkin...
# 2571    06e241649bee58ac  I CANNOT BELIEVE THIS WHAT THE #@@%K\nif you c...
# 2593    06f0b97018548ab9  jd2718 the sock fiend \n\nnow hes lying out hi...
# 2653    07200a455b9886d3               nonsense \n\nare you a boy or a girl
# 2751    07626231559eb6cb   Are you kidding? Take your threats and shove em.
# 3142    0878fbd30d4aa6fe  Hey. It is my judgement in the matter of David...
# 3166    088f9a2bfb09a548  "\n\nIt's a stupid project.\n\nWikipedia shoul...
# 3321    08f4270aad0adde8  UNBELIEVABLE you went ahead and removed the se...
# ...                  ...                                                ...
# 155312  bbf9b3bfdda67f5f  And claim that a public computer ID is a sockp...
# 155321  bc15e8f5aa016a16  lol it's almost (...*almost*) as if Wikipedia ...
# 155538  bf82c8b8473745d4  Message\n\nHey Dx927 you're a fat ugly cunt wi...
# 155707  c2569ca2b59b3cba                                Stay in the closet.
# 155765  c350b56646851989  If you knew any better you would know that onl...
# 155791  c3bbea2e8c3fea46  Dude, u got a stick in ur ass, lemme edit the ...
# 155813  c41ea4aaea119b55  , 1 June 2009 (UTC)\n\nPicking fight\n\nYeah, ...
# 155823  c43833cfee695e07  "\n\nMessage\n\nHey Coolrunner87, you tedious ...
# 155912  c5c19e34d13396dd  "\n\nThe efforts by Elonka, et. al., to ratify...
# 156094  c8e68dba9aae369b                        when the hell did i do that
# 156118  c93ca6548f0ede6f  _   ANYWAY, GOTTA MAKE OUT ANOTHER ACCOUNT IF ...
# 156386  cd6f62a15b469c1b  "   \nShare on printPrint Share on emailEmail ...
# 156440  ce344580a845500c  "\n\nYOU REMOVE MY MESSAGE OF BANNING MYSELF??...
# 156621  d13effbe84553680  "\n\n Adam Rose \n\n  John Cena lover Why do y...
# 156755  d3153b937c456bb1  I'm proud of mine. You are shames, thats why y...
# 156839  d441d4727928e963  ===If the editors here cannot respond to even ...
# 157515  df82be2be7f92464  Did you try any calm discussion?  No, you left...
# 157516  df853a84c5d71c81  But then he wouldn't be able to sit here argui...
# 157683  e20a6e35429f2266  Associação Académica de Coimbra 2\nOne user di...
# 157694  e22a2557c33d5df3                       tno thanks mate p i s s offe
# 158005  e73fd6cabdc72854  All enjoyed by Stumbahnfuhrer Garage . as corr...
# 158097  e8aead5da810b79b  Cram ==\nPlease stop reverting Cram, the book ...
# 158148  e96f39e6855b7e04  "\n wow, you sure do ""talk"", ""talk:"", ""Ta...
# 158330  ec35f47c57f00604  So it's not German? Than what the hell spellin...
# 158476  ee84acb7438e0d33  Why?\nWhy do you get soo offended when i call ...
# 158615  f0b46600c7cf2515  """And at least Castro was trying to liberate ...
# 158746  f319deef4713c05c  Tiger Sharks are damn weak! Great Whites are a...
# 158793  f3d62179cdb93e58  Hey FayssalFag, will you ever get a life offli...
# 159458  fe13842dd9171fdc  I'm gay, I'm gay and I don't care who knows it...
# 159471  fe5b78a6d22198c4  If some people are anti-catholic then their ju...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate target_str
# 61          0             0        0       0       0              0     000000
# 175         0             0        0       0       0              0     000000
# 179         0             0        0       0       1              0     000010
# 368         0             0        0       0       0              0     000000
# 503         1             0        0       0       0              0     100000
# 527         0             0        1       0       0              0     001000
# 590         1             0        0       0       0              0     100000
# 831         0             0        0       0       0              0     000000
# 923         0             0        0       0       0              0     000000
# 946         0             0        0       0       0              0     000000
# 1132        0             0        0       0       0              0     000000
# 1150        0             0        0       0       0              0     000000
# 1430        0             0        0       0       0              0     000000
# 1495        0             0        0       0       0              0     000000
# 1555        0             0        1       0       0              0     001000
# 1624        0             0        0       0       1              0     000010
# 1657        0             0        0       0       0              0     000000
# 1952        0             0        0       0       0              0     000000
# 2322        1             0        0       0       0              0     100000
# 2378        1             0        0       0       0              0     100000
# 2412        0             0        0       0       0              0     000000
# 2494        1             0        0       0       0              0     100000
# 2537        0             0        1       0       1              0     001010
# 2571        1             0        0       0       0              0     100000
# 2593        0             0        1       0       0              0     001000
# 2653        0             0        0       0       0              0     000000
# 2751        0             0        0       0       0              0     000000
# 3142        0             0        0       0       0              0     000000
# 3166        1             0        0       0       0              0     100000
# 3321        1             0        0       0       0              0     100000
# ...       ...           ...      ...     ...     ...            ...        ...
# 155312      0             0        0       0       0              0     000000
# 155321      1             0        0       0       0              0     100000
# 155538      0             0        1       0       1              0     001010
# 155707      1             0        0       0       0              0     100000
# 155765      0             0        0       0       0              0     000000
# 155791      0             0        1       0       1              0     001010
# 155813      0             0        0       0       0              0     000000
# 155823      0             0        0       0       0              0     000000
# 155912      1             0        0       0       0              0     100000
# 156094      0             0        0       0       0              0     000000
# 156118      1             0        0       0       0              0     100000
# 156386      0             0        0       0       0              0     000000
# 156440      0             0        0       0       0              0     000000
# 156621      0             0        1       0       1              0     001010
# 156755      0             0        0       0       1              0     000010
# 156839      0             0        0       0       1              0     000010
# 157515      0             0        0       0       0              0     000000
# 157516      0             0        0       0       0              0     000000
# 157683      0             0        0       0       0              0     000000
# 157694      1             0        0       0       0              0     100000
# 158005      0             0        0       0       0              0     000000
# 158097      0             0        0       0       0              0     000000
# 158148      1             0        0       0       0              0     100000
# 158330      0             0        0       0       0              0     000000
# 158476      0             0        0       0       0              0     000000
# 158615      0             0        1       0       1              0     001010
# 158746      0             0        0       0       0              0     000000
# 158793      0             0        1       0       1              0     001010
# 159458      0             0        0       0       0              0     000000
# 159471      0             0        0       0       0              0     000000
#
# [1182 rows x 9 columns]

# %%
train[mask].sample(1).values
# Out:
# array([['6df712a31fc7d2a4',
#         "STOP Threatning me.  Why don't you falsely accuse me of murder?",
#         0, 0, 0, 0, 0, 0, '000000']], dtype=object)

# %%
train.comment_text.loc[158097]
# Out:
# "Cram ==\nPlease stop reverting Cram, the book was used is Cram's Big Dumb Book of Stupid Lists!! Please stop it!! \n\n=="

# %%
train.loc[train.id == '82cf42b73acbcfbf']
#48928 - mark as threat
# Out:
#                      id                                       comment_text  \
# 48928  82cf42b73acbcfbf  Apparently I wasn't clear enough the first tim...
#
#        toxic  severe_toxic  obscene  threat  insult  identity_hate target_str
# 48928      0             0        1       0       0              0     001000

# %%
train.loc[train.comment_text.str.contains("despicable"), 'toxic'].value_counts(normalize=True)
# Out:
# 0    0.833333
# 1    0.166667
# Name: toxic, dtype: float64

# %%
import eli5
eli5.show_weights(model, vec=vec, top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.754
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__gay
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.346
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__nigger
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.150
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__nigg
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.068
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__gay
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.925
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__jew
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.707
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__gg
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.531
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__nig
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.158
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>gay
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.094
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__igg
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.462
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__nazi
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.364
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__homo
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.297
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__jew
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.221
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__homosexual
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.186
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__homo
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.086
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__gga
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.029
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__fag
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.706
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__black
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.659
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__gger
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.630
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__niggers
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.541
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word__hate
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.499
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         char__<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>jew
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.496
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-ali

# %%
for col in label_cols:
    print(train[col].value_counts(normalize=True))
    print(train.loc[train.comment_text.str.count("[A-Z]{1}[a-z]+") > 10, col].value_counts(normalize=True))
# Out:
# 0    0.904156
# 1    0.095844
# Name: toxic, dtype: float64
# 0    0.955709
# 1    0.044291
# Name: toxic, dtype: float64
# 0    0.990004
# 1    0.009996
# Name: severe_toxic, dtype: float64
# 0    0.997116
# 1    0.002884
# Name: severe_toxic, dtype: float64
# 0    0.947052
# 1    0.052948
# Name: obscene, dtype: float64
# 0    0.978784
# 1    0.021216
# Name: obscene, dtype: float64
# 0    0.997004
# 1    0.002996
# Name: threat, dtype: float64
# 0    0.999135
# 1    0.000865
# Name: threat, dtype: float64
# 0    0.950636
# 1    0.049364
# Name: insult, dtype: float64
# 0    0.981252
# 1    0.018748
# Name: insult, dtype: float64
# 0    0.991195
# 1    0.008805
# Name: identity_hate, dtype: float64
# 0    0.996122
# 1    0.003878
# Name: identity_hate, dtype: float64

# %%
np.mean(y_test_preds, axis=0)
# Out:
# array([0.28327398, 0.06538349, 0.18888107, 0.01907626, 0.17942272,
#        0.06447977])

# %%
(y_preds[:,0] - y_preds[:,4]) >
